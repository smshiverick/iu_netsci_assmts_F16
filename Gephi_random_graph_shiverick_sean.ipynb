# %% [markdown]
# ## Praxis: Gephi - Random Graphs
#    ### Fall 2016 Network Science - Sean Shiverick
# ##### Create a new Jupyter notebook and use random graph generator tool introduced in the last assignment to create a random graph with same number of nodes and about same average degree and number of edges as real graph.

# %%
# Create Random graph based on Les Miserables character network

import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

random_graph = nx.erdos_renyi_graph(77, 0.09)
print(nx.info(random_graph))
# Out:
# Name: gnp_random_graph(77,0.09)
# Type: Graph
# Number of nodes: 77
# Number of edges: 247
# Average degree:   6.4156

# %%
# Draw the graph and display plot; write the plot as .gml file

nx.draw(random_graph)
plt.show

nx.write_gml(random_graph, "random_lesmis.gml")

# %%
# Create Random graph based on C. elegans neural network

random_graph2 = nx.erdos_renyi_graph(297, 0.054)
print(nx.info(random_graph2))
# Out:
# Name: gnp_random_graph(297,0.054)
# Type: Graph
# Number of nodes: 297
# Number of edges: 2338
# Average degree:  15.7441

# %%
# Draw the graph and display; write the graph as .gml file

nx.draw(random_graph2)
plt.show

nx.write_gml(random_graph2, "random_celegans.gml")
